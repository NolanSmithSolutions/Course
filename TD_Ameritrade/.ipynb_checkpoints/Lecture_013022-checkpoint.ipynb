# %% [markdown]
# # TD Ameritrade – Python API
# The TD Ameritrade API allows users to easily execute trades and pull both fundamental and technical data on all public equity and debt securities.  It also offers data on publicly traded derivatives such as stock options, index & commodity futures, and interest rate swaps.
#
# ### Set Up
# 1.	Go to https://developer.tdameritrade.com/
# 2.	Click “Register”
# 3.	Fill in requested fields
# 4.	Once Registered, click on “My Apps”
# 5.	Select “Add a new App”
# 6.	Fill out the fields as follows
# 7.	Once the app is approved, click on the app name and navigate to the “KEYS” tab:
# 8.	Now that your app is registered copy the “Key” from the above section, and head over to the included Jupyter notebook to test out some of the functionality of the API.
#
# ### Python Set up for the API
# Now that your app is registered, you will be able to pull a wealth of info from the API.
# #### Needed Packages
# 1.	requests
# 2.	pandas
# 3.	time
# 4.  matplotlib
# 5.  numpy
# 6.  seaborn
# 7.  statsmodels.api
# 8.  math
# 9. statistics
#
# #### Needed Configuration Inputs
# 1.	Ticker file path.  This is a CSV file that you will create that has the set of tickers you wish to analyze.  Place this file in your download's folder.
# 2.	API Key: pulled from the developer page
# 3.	Define these required configurations in the Jupyter notebook:
#
#
# ### Data & Analysis
#
# 1. Downloading fundamental data
# 2. Downloading pricing data
# 3. Calculating Annualized Returns
# 4. Running a Regression Model

# %%
######################
###Libraries & Paths##
######################

import requests
import pandas as pd
from pandas.io.json import json_normalize
import time
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import math
import statistics

# %% [markdown]
# ## Snagging Downloaded Files
#
# The "get_download_path" function allows python to find your downloads folder's filepath and use it pull open your ticker list csv file.  The output of the below cell should be a list of the tickers you inputted in the ticker list csv file.

# %%
def get_download_path():
    """Returns the default downloads path for linux or windows"""
    if os.name == 'nt':
        import winreg
        sub_key = r'SOFTWARE\Microsoft\Windows\CurrentVersion\Explorer\Shell Folders'
        downloads_guid = '{374DE290-123F-4565-9164-39C4925E467B}'
        with winreg.OpenKey(winreg.HKEY_CURRENT_USER, sub_key) as key:
            location = winreg.QueryValueEx(key, downloads_guid)[0]
        return location
    else:
        return os.path.join(os.path.expanduser('~'), 'downloads')

ticker_path = get_download_path()+'/Ticker_List.csv'
key = 'RGOLSJPSTGVAN4NTN4DLWJE71SU7SIH0'  ##PUT YOUR KEY HERE

tickers_file = pd.read_csv(ticker_path, header=None)
tickers = []
for ticker in tickers_file.values:
    tickers.append(ticker[0])
print(tickers)
# Out:
# ['AAPL', 'TSLA', 'MSFT']

# %% [markdown]
# ## Manual Edits
# Uncomment out the below cell and edit the list's content to replace the tickers you wish to evaluate.

# %%
#tickers
tickers = ['AAPL']

# %% [markdown]
# ## Defined Functions
# While this code block does not run anything on its own, it holds functions that will be used later in the program.  The TD Ameritrade API contains functions that don't always output data in the most clean (useable) format, so we have developed some functions that "scrub" the output so that it returns in a better format.  Each function will be examined more thouroughly as we go through the lecture, but they will allow us to analyze a public stock from both a quantitative and qualitative perspective.

# %%
def get_price_hist(ticker,period,key):
    time.sleep(1)
    endpoint = 'https://api.tdameritrade.com/v1/marketdata/'+ticker+'/pricehistory'

    ##Define Payload
    payload = {'apikey': key,
    'periodType': 'year',
    'peirod':period,
    'frequencyType':'daily'}

    ### make request
    try:
        content = requests.get(url = endpoint, params = payload)
    except:
        print('API error, please review.')
        
    ### Convert to dictionary
    dictlist = []
    data = content.json()

    for key, value in data.items():
        temp = [key,value]
        dictlist.append(temp)
        
    try:
        hist_data = pd.DataFrame(dictlist[0][1])
        hist_data['ticker'] = ticker
        hist_data['datetime'] = pd.to_datetime(hist_data['datetime'],unit='ms')
        return hist_data
    except:
        df = pd.DataFrame()
        return df
    

def get_fundamental_from_td(ticker,key):
    time.sleep(1)
    endpoint = 'https://api.tdameritrade.com/v1/instruments'
    projection = 'fundamental'

    ##Define Payload
    payload = {'apikey': key,
               'symbol' : ticker,
                'projection': projection,
                }
    
    ### make request
    try:
        content = requests.get(url = endpoint, params = payload)
    except:
        print('API error, please review.')
        
    ### Convert to dictionary
    dictlist = []
    data = content.json()
    for key, value in data.items():
        temp = [key,value]
        dictlist.append(temp)
        
    try:
        df = pd.DataFrame(dictlist[0][1]).T.reset_index(drop=True).iloc[0]
        return df
    except:
        print(dictlist)
        df = pd.DataFrame()
        print(ticker + " not valid.")
        return df

def scrub_fundamental_data(tickers,key):
    master = pd.DataFrame()
    count = 1
    for ticker in tickers:
        temp = get_fundamental_from_td(ticker,key)
        temp = pd.DataFrame(temp).T
        hist_data = get_annual_returns([ticker],key)
        try:
            temp.columns = ['beta', 'bookValuePerShare', 'currentRatio', 'divGrowthRate3Year',
           'dividendAmount', 'dividendDate', 'dividendPayAmount',
           'dividendPayDate', 'dividendYield', 'epsChange', 'epsChangePercentTTM',
           'epsChangeYear', 'epsTTM', 'grossMarginMRQ', 'grossMarginTTM', 'high52',
           'interestCoverage', 'low52', 'ltDebtToEquity', 'marketCap',
           'marketCapFloat', 'netProfitMarginMRQ', 'netProfitMarginTTM',
           'operatingMarginMRQ', 'operatingMarginTTM', 'pbRatio', 'pcfRatio',
           'peRatio', 'pegRatio', 'prRatio', 'quickRatio', 'returnOnAssets',
           'returnOnEquity', 'returnOnInvestment', 'revChangeIn', 'revChangeTTM',
           'revChangeYear', 'sharesOutstanding', 'shortIntDayToCover',
           'shortIntToFloat', 'ticker', 'totalDebtToCapital', 'totalDebtToEquity',
           'vol10DayAvg', 'vol1DayAvg', 'vol3MonthAvg']
            temp = pd.merge(temp, hist_data, on='ticker')
        except:
            continue
        
        master = master.append(temp).reset_index(drop=True)
        count+= 1
    return master

def scrub_price_hist(tickers,key):
    master = pd.DataFrame()
    for ticker in tickers:
        price_data = get_price_hist(ticker,1,key)
        master = master.append(price_data, ignore_index=True)
    return master

def get_annual_returns(tickers,key):
    master = pd.DataFrame()
    for ticker in tickers:
        try:
            price_data = get_price_hist(ticker,1,key).iloc[::-1]
            return_percent = price_data['close'].iloc[0] / price_data['close'].iloc[-1] -1
            df = pd.DataFrame({"ticker":ticker,  
                               "Annual_Return_Percent":return_percent},
                               index = [0])
            master = master.append(df, ignore_index=True)
        except:

            print('error with', ticker)
    return master

# %% [markdown]
# ## Preliminary Stock analysis
# This section will show you how to calculate a stocks beta relative to a market proxy using 1 year daily data.  When
# picking securities for yours or another's portolio, it is first helpful to know the risk tolerance of the investmentor
# relative to the risk of investing in the broad market.  Beta will allow us to estimate this for any number of stocks, then
# make relative conclusions.

# %%
# This cell will get the price history for our short list.
aapl_data = scrub_price_hist(tickers,key)
aapl_data.head()
# Out:
#      open    high     low   close     volume            datetime ticker
# 0  139.52  141.99  136.70  137.09  142621130 2021-01-28 06:00:00   AAPL
# 1  135.83  136.74  130.21  131.96  177523810 2021-01-29 06:00:00   AAPL
# 2  133.75  135.38  130.93  134.14  106239823 2021-02-01 06:00:00   AAPL
# 3  135.73  136.31  134.61  134.99   83305367 2021-02-02 06:00:00   AAPL
# 4  135.76  135.77  133.61  133.94   89880937 2021-02-03 06:00:00   AAPL

# %%
#To make analysis easier let's only look at the close and date and sort the date in descending order
aapl_data = aapl_data[['close','datetime','ticker']]
aapl_data = aapl_data.sort_values(by = 'datetime', ascending = False)
aapl_data.head()
# Out:
#       close            datetime ticker
# 253  170.33 2022-01-28 06:00:00   AAPL
# 252  159.22 2022-01-27 06:00:00   AAPL
# 251  159.69 2022-01-26 06:00:00   AAPL
# 250  159.78 2022-01-25 06:00:00   AAPL
# 249  161.62 2022-01-24 06:00:00   AAPL

# %%
#Add a new column to show daily returns 
aapl_data['AAPL_Return_%'] = aapl_data['close'] / aapl_data['close'].shift(-1) - 1
aapl_data.rename(columns={'close': 'AAPL_Close'}, inplace=True)
aapl_data.drop(columns = ['ticker'], inplace = True)
aapl_data.head()
# Out:
#      AAPL_Close            datetime  AAPL_Return_%
# 253      170.33 2022-01-28 06:00:00       0.069778
# 252      159.22 2022-01-27 06:00:00      -0.002943
# 251      159.69 2022-01-26 06:00:00      -0.000563
# 250      159.78 2022-01-25 06:00:00      -0.011385
# 249      161.62 2022-01-24 06:00:00      -0.004864

# %%
# When starting an analysis of a stock, it is helpful to understand how the security performs relative to the market.
# To accomplish this, we will use the S&P 500 as a proxy for the market, and calculate the beta of the stock relative 
# to the proxy.  This cell replicates the above for ticker SPY which is one of the most liquid ETFs the tracks the S&P 500
spy_data = scrub_price_hist(['SPY'],key)
spy_data = spy_data[['close','datetime','ticker']]
spy_data = spy_data.sort_values(by = 'datetime', ascending = False)
spy_data['SPY_Return_%'] = spy_data['close'] / spy_data['close'].shift(-1) - 1
spy_data.rename(columns={'close': 'SPY_Close'}, inplace=True)
spy_data.drop(columns = ['ticker'], inplace = True)
spy_data.head()
# Out:
#      SPY_Close            datetime  SPY_Return_%
# 253     441.95 2022-01-28 06:00:00      0.024835
# 252     431.24 2022-01-27 06:00:00     -0.004938
# 251     433.38 2022-01-26 06:00:00     -0.002509
# 250     434.47 2022-01-25 06:00:00     -0.012209
# 249     439.84 2022-01-24 06:00:00      0.004247

# %%
#Now we'll merge the two sets
consol_data = pd.merge(aapl_data,spy_data,on=['datetime'], how = 'left').dropna() 
#note that you need to dropna because of how we calc'd returns, the last date in the set will not have a return value 

consol_data.head()
# Out:
#    AAPL_Close            datetime  AAPL_Return_%  SPY_Close  SPY_Return_%
# 0      170.33 2022-01-28 06:00:00       0.069778     441.95      0.024835
# 1      159.22 2022-01-27 06:00:00      -0.002943     431.24     -0.004938
# 2      159.69 2022-01-26 06:00:00      -0.000563     433.38     -0.002509
# 3      159.78 2022-01-25 06:00:00      -0.011385     434.47     -0.012209
# 4      161.62 2022-01-24 06:00:00      -0.004864     439.84      0.004247

# %%
##Now calc beta using statsmodels
x = consol_data[['SPY_Return_%']]
y = consol_data[['AAPL_Return_%']]

model = sm.OLS(y, x)
results = model.fit()
print('Beta: '+str(round(results.params[0],2)))

# How does this value compare to other sources such as Yahoo Finance (who uses a 5 year monthly model compared to 
# our 1 year daily)? Should this cause some skepticism when looking at results from models you didn't build?
# Out:
# Beta: 1.37

# %% [markdown]
# ## -------------PRACTICE-------------

# %% [markdown]
# 1. Pull the 1 year price history using the scrub_price_hist function of any stock you like.

# %% [markdown]
# 2. Clean up the output so it mirrors our output for Apple.

# %% [markdown]
# 3.  Think of another market proxy besides the S&P 500, pull it's data, and clean it up.

# %% [markdown]
# 4. Merge the two data sets, so that it mirrors the 'consol_data' variable.  Then merge in the SPY data.

# %% [markdown]
# 5. Calculate the beta of your new stock relative to both SPY and your new market proxy.  Are they different significantly?
#    Consider why they may be different.

# %% [markdown]
# ## Another common measure of risk: Volatility
# Much like beta, annual standard deviation of returns (more commonly known as volatility), can be a helpful tool to guage the relative risk a particular asset poses to a portfolio.  Let's see how we might go about calculating that for Apple.

# %%
#Start with our Aaple data
aapl_data.head()
# Out:
#      AAPL_Close            datetime  AAPL_Return_%
# 253      170.33 2022-01-28 06:00:00       0.069778
# 252      159.22 2022-01-27 06:00:00      -0.002943
# 251      159.69 2022-01-26 06:00:00      -0.000563
# 250      159.78 2022-01-25 06:00:00      -0.011385
# 249      161.62 2022-01-24 06:00:00      -0.004864

# %%
# Remember that the covariance of a random variable with itself is the same as its variance.
aapl_vol = math.sqrt(pd.DataFrame([aapl_data['AAPL_Return_%'],aapl_data['AAPL_Return_%']]).T.cov().iloc[0,0])*math.sqrt(252)
print('Apple Volatility: '+str(round(aapl_vol*100,2))+'%')
# Out:
# Apple Volatility: 24.97%

# %%
# How does this compare to SPY?
spy_vol = math.sqrt(pd.DataFrame([spy_data['SPY_Return_%'],spy_data['SPY_Return_%']]).T.cov().iloc[0,0])*math.sqrt(252)
print('SPY Volatility: '+str(round(spy_vol*100,2))+'%')
# Out:
# SPY Volatility: 13.45%

# %% [markdown]
# Are these results surprising?  Think about the implications of an annual volatility of over 20%, and how such a security would
# behave if it fell out of the market's favor.

# %% [markdown]
# ## Fundamental Data
# Many critics argue any form of technical analysis is a waste of time and should be avoided.  Instead, they will argue for
# fundament analysis, or effectively looking at various accounting measures to understand the health of a firm, and judge it's
# performance relative to its peers.

# %%
# This cell pulls the fundamental financial data from TD Ameritrade, cleans it up into a useable format and spits it out 
# in a nice table format using the Pandas package.  Note that book value per share is not
# entirely accurate, all other metrics have been vetted. Let's look at the whole S&P 500.
tickers =['AAPL','MSFT','AMZN','FB','GOOGL','GOOG','BRK.B','JNJ','V','PG','JPM','NVDA','UNH','MA','HD','VZ','DIS','NFLX',
          'ADBE','PYPL','CRM','MRK','T','INTC','PFE','CMCSA','BAC','WMT','KO','PEP','ABT','CSCO','XOM','TMO','ABBV','MCD',
          'COST','ACN','CVX','AMGN','MDT','AVGO','NKE','NEE','BMY','UNP','LIN','LLY','TXN','QCOM','DHR','PM','LOW','HON',
          'ORCL','UPS','AMT','IBM','C','SBUX','LMT','MMM','AMD','FIS','CHTR','WFC','RTX','BA','BLK','NOW','INTU','SPGI',
          'ISRG','MDLZ','GILD','CAT','MO','CVS','BKNG','ZTS','PLD','TGT','BDX','AXP','ANTM','VRTX','TJX','CCI','DE','D',
          'EQIX','TMUS','APD','CL','CI','SYK','GS','MS','CME','DUK','ATVI','ADP','BSX','MMC','CSX','REGN','SO','ITW','CB',
          'ICE','SHW','PGR','FISV','HUM','GE','NSC','NEM','FDX','NOC','AMAT','TFC','EW','KMB','USB','MU','GPN','ILMN',
          'ADSK','ECL','DG','EL','PNC','AON','MCO','BIIB','LRCX','WM','DD','ADI','BAX','ROP','GM','EMR','ETN','SCHW','AEP',
          'LHX','DLR','COP','EA','XEL','DXCM','GIS','CTSH','DOW','EXC','ORLY','HCA','SRE','GD','SBAC','EBAY','ROST','CNC',
          'CMG','COF','PSA','TEL','STZ','IDXX','APH','INFO','JCI','SYY','CMI','SNPS','TWTR','MNST','WEC','MET','A','TROW',
          'BK','VRSK','TRV','ES','MSCI','ALL','PCAR','PPG','IQV','ZBH','AZO','YUM','MAR','CDNS','HPQ','TT','KR','KLAC','F',
          'PRU','WBA','CLX','AFL','CTAS','BLL','ANSS','PEG','MSI','WLTW','PH','HLT','KMI','ROK','SLB','PSX','MCHP','AWK',
          'WELL','ADM','AIG','TDG','FAST','WMB','OTIS','GLW','RMD','MCK','ED','SWK','MKC','CARR','BBY','ALXN','XLNX','EOG',
          'PAYX','STT','MTD','DHI','FCX','DTE','CHD','ALGN','AVB','O','AME','SWKS','VFC','FTV','PPL','APTV','HSY','SPG',
          'CERN','LUV','DLTR','CTVA','MPC','CPRT','WY','LEN','ARE','VRSN','EQR','VLO','EFX','KHC','RSG','FLT','EIX','ETR',
          'WST','AJG','AEE','DAL','ODFL','FRC','AMP','TSN','LYB','KSU','MXIM','TFX','LVS','TTWO','KEYS','NTRS','DFS','KMX',
          'CMS','AMCR','CAG','MKTX','LH','AKAM','K','VTR','TSCO','VMC','CDW','CTXS','CBRE','INCY','VAR','FE','DOV','PXD',
          'COO','FTNT','VIAC','GWW','BR','PEAK','FITB','HOLX','MAS','EXPD','IP','XYL','NDAQ','DPZ','ESS','CAH','BF.B',
          'GRMN','ABC','DGX','HIG','GPC','EXR','HRL','DRE','NUE','SYF','EXPE','FMC','NVR','MTB','STE','ZBRA','ULTA','PAYC',
          'QRVO','IEX','MAA','SIVB','TIF','HAL','TYL','IFF','CHRW','SJM','MLM','WAT','LNT','CE','URI','BXP','PKI','KEY',
          'WAB','NLOK','HPE','RCL','JKHY','ABMD','CINF','EVRG','IR','J','HES','ETFC','OMC','DRI','CFG','JBHT','LDOS','TDY',
          'ATO','AES','MGM','IT','FBHS','ANET','RF','PHM','PFG','OKE','WDC','EMN','CNP','STX','WHR','AAP','NTAP','BIO',
          'CTL','UDR','HBAN','CBOE','HAS','ALB','LKQ','OXY','PKG','FOXA','XRAY','AVY','CXO','WU','UAL','HSIC','ALLE','BKR',
          'RJF','WRB','LW','TXT','UHS','CCL','L','IRM','BWA','RE','DISH','HST','PNW','GL','WRK','LYV','NI','SNA','NRG',
          'MYL','WYNN','CPB','JNPR','DVA','ROL','PNR','COG','PWR','FFIV','AIZ','LNC','TAP','CF','REG','AAL','IPG','HWM',
          'PRGO','AOS','LB','DISCK','NWL','MOS','RHI','SEE','BEN','HII','CMA','IPGP','VNO','HBI','FRT','MHK','LEG','ZION',
          'NWSA','AIV','NLSN','FANG','ALK','DXC','KIM','PVH','APA','NCLH','PBCT','FLIR','NBL','FOX','NOV','TPR','IVZ',
          'UNM','SLG','RL','DVN','GPS','FLS','MRO','KSS','DISCA','XRX','HFC','FTI','HRB','UAA','UA','NWS','COTY']
fundamental_data=scrub_fundamental_data(tickers,key)
fundamental_data.T
# Out:
# []
# ALXN not valid.
# error with ALXN
# error with KSU
# []
# MXIM not valid.
# error with MXIM
# []
# VAR not valid.
# error with VAR
# []
# TIF not valid.
# error with TIF
# []
# ETFC not valid.
# error with ETFC
# error with CTL
# []
# CXO not valid.
# error with CXO
# []
# MYL not valid.
# error with MYL
# error with COG
# []
# LB not valid.
# error with LB
# []
# FLIR not valid.
# error with FLIR
# []
# NBL not valid.
# error with NBL
#                                            0                        1    \
# beta                                    1.1599                  0.88019
# bookValuePerShare                            0                  15.4153
# currentRatio                           1.03781                   2.2473
# divGrowthRate3Year                           0                        0
# dividendAmount                            0.88                     2.48
# dividendDate           2021-11-05 00:00:00.000  2022-02-16 00:00:00.000
# dividendPayAmount                         0.22                     0.62
# dividendPayDate        2021-11-11 00:00:00.000  2022-03-10 00:00:00.000
# dividendYield                             0.52                      0.8
# epsChange                                    0                        0
# epsChangePercentTTM                    62.8302                  39.9902
# epsChangeYear                          24.7651                  22.3343
# epsTTM                                 6.02325                  9.39915
# grossMarginMRQ                         43.7638                  67.2131
# grossMarginTTM                         43.0191                  68.8258
# high52                                  182.94                   349.67
# interestCoverage                       942.909                        0
# low52                                   116.21                   224.26
# ltDebtToEquity                         148.236                   38.442
# marketCap                          2.78223e+06              2.31098e+06
# marketCapFloat                         16322.8                  7480.94
# netProfitMarginMRQ                     27.9398                  36.2763
# netProfitMarginTTM                     26.5791                  38.4986
# operatingMarginMRQ                     33.4729                   42.998
# operatingMarginTTM                     30.9003                  42.5169
# pbRatio                                 38.694                  14.4488
# pcfRatio                               24.8702                  27.4552
# peRatio                                28.2787                  32.7966
# pegRatio                              0.450082                 0.820116
# prRatio                                7.35412                  12.4984
# quickRatio                             0.99799                  2.20835
# returnOnAssets                         27.3528                  22.0891
# returnOnEquity                         145.567                  49.0515
# returnOnInvestment                     44.1841                  28.5008
# revChangeIn                            48.6864                   14.147
# revChangeTTM                           28.6222                  20.6277
# revChangeYear                                0                        0
# sharesOutstanding                  1.63194e+10              7.49687e+09
# shortIntDayToCover                           0                        0
# shortIntToFloat                              0                        0
# ticker                                    AAPL                     MSFT
# totalDebtToCapital                     63.0607                  29.6545
# totalDebtToEquity                      170.714                  42.1555
# vol10DayAvg                        1.16936e+08              5.74117e+07
# vol1DayAvg                         1.16464e+08              5.73858e+07
# vol3MonthAvg                       2.04189e+09              6.79047e+08
# Annual_Return_Percent                 0.242468                 0.290169
#
#                                2            3            4            5    \
# beta                       1.13461      1.27195      1.05125      1.05125
# bookValuePerShare          45.5615      23.7077       13.489       13.489
# currentRatio               1.11724      4.23428      2.97999      2.97999
# divGrowthRate3Year               0            0            0            0
# dividendAmount                   0            0            0            0
# dividendDate
# dividendPayAmount                0            0            0            0
# dividendPayDate
# dividendYield                    0            0            0            0
# epsChange                        0            0            0            0
# epsChangePercentTTM        49.7688      65.8864      104.432      104.432
# epsChangeYear                    0      18.4923      70.6899      70.6899
# epsTTM                     51.1416      13.9885      103.832      103.832
# grossMarginMRQ             43.2101      80.1069      57.5832      57.5832
# grossMarginTTM             41.3071      80.8502      56.5106      56.5106
# high52                     3773.08       384.33      3019.33         3037
# interestCoverage            7.9541            0            0            0
# low52                      2707.04        253.5      1801.56       1810.2
# ltDebtToEquity             54.6283      0.38017      5.84216      5.84216
# marketCap              1.46036e+06       839285  1.76988e+06  1.76988e+06
# marketCapFloat              439.39      2350.68      617.859      617.859
# netProfitMarginMRQ         2.85168      31.6925      29.0795      29.0795
# netProfitMarginTTM         5.72926        35.88      29.5213      29.5213
# operatingMarginMRQ         4.37859       35.929      32.2968      32.2968
# operatingMarginTTM         6.17776      41.7903      30.2997      30.2997
# pbRatio                    12.0137      6.31881       7.2484       7.2484
# pcfRatio                   25.0276      17.4415      21.2382      21.2382
# peRatio                    56.3057      21.5684      25.6858      25.6858
# pegRatio                   1.13134     0.327358     0.245958     0.245958
# prRatio                    3.18881       7.4716      7.39886      7.39886
# quickRatio                 0.86777            0      2.95931      2.95931
# returnOnAssets             7.89606      25.5071      21.8413      21.8413
# returnOnEquity             25.8317      32.1031      30.8721      30.8721
# returnOnInvestment         11.9623      28.1584      26.3174      26.3174
# revChangeIn                      0            0      5.23271      5.23271
# revChangeTTM               31.6199      42.2331      39.3153      39.3153
# revChangeYear                    0            0            0            0
# sharesOutstanding      5.07148e+08  2.36628e+09   3.0081e+08  3.17738e+08
# shortIntDayToCover               0            0            0            0
# shortIntToFloat                  0            0            0            0
# ticker                        AMZN           FB        GOOGL         GOOG
# totalDebtToCapital         35.6738      0.43229      5.61049      5.61049
# totalDebtToEquity          55.4577      0.43416      5.94397      5.94397
# vol10DayAvg            4.48491e+06  2.41892e+07   2.0896e+06  1.63804e+06
# vol1DayAvg              4.4807e+06  2.41759e+07  2.08662e+06  2.08662e+06
# vol3MonthAvg            7.0851e+07  4.28356e+08  3.25946e+07  3.25946e+07
# Annual_Return_Percent    -0.110594     0.138528     0.439143     0.430828
#
#                                            6                        7    \
# beta                                   0.67608                  0.85725
# bookValuePerShare                            0                  3.35863
# currentRatio                                 0                   1.3952
# divGrowthRate3Year                           0                        0
# dividendAmount                            4.24                      1.5
# dividendDate           2022-02-18 00:00:00.000  2021-11-10 00:00:00.000
# dividendPayAmount                         1.06                    0.375
# dividendPayDate        2022-03-08 00:00:00.000  2021-12-07 00:00:00.000
# dividendYield                             2.47                     0.66
# epsChange                                    0                        0
# epsChangePercentTTM                    44.6787                        0
# epsChangeYear                          172.517                        0
# epsTTM                                 7.81307                        0
# grossMarginMRQ                         67.9286                        0
# grossMarginTTM                         68.1632                        0
# high52                                  179.92                   252.67
# interestCoverage                       116.234                        0
# low52                                   151.47                    190.1
# ltDebtToEquity                               0                  48.8285
# marketCap                               452254                   480222
# marketCapFloat                          2630.3                  1660.68
# netProfitMarginMRQ                     19.0937                        0
# netProfitMarginTTM                     22.2639                        0
# operatingMarginMRQ                     19.4969                        0
# operatingMarginTTM                     24.2879                        0
# pbRatio                                      0                  14.4124
# pcfRatio                               20.8518                        0
# peRatio                                21.9875                        0
# pegRatio                              0.492125                        0
# prRatio                                4.82275                        0
# quickRatio                                   0                        0
# returnOnAssets                               0                        0
# returnOnEquity                               0                        0
# returnOnInvestment                           0                        0
# revChangeIn                             6.2816                        0
# revChangeTTM                           13.5511                        0
# revChangeYear                                0                        0
# sharesOutstanding                   2.6326e+09              1.66742e+09
# shortIntDayToCover                           0                        0
# shortIntToFloat                              0                        0
# ticker                                     JNJ                        V
# totalDebtToCapital                           0                  36.6285
# totalDebtToEquity                            0                  57.7996
# vol10DayAvg                        9.31359e+06               1.2952e+07
# vol1DayAvg                          9.3063e+06              1.29442e+07
# vol3MonthAvg                       1.63235e+08              2.35212e+08
# Annual_Return_Percent                0.0155474                 0.150237
#
#                                            8                        9    ...  \
# beta                                   0.43508                  1.09004  ...
# bookValuePerShare                            0                  6.95567  ...
# currentRatio                           0.67176                        0  ...
# divGrowthRate3Year                           0                        0  ...
# dividendAmount                          3.4792                        4  ...
# dividendDate           2022-01-20 00:00:00.000  2022-01-05 00:00:00.000  ...
# dividendPayAmount                       0.8698                        1  ...
# dividendPayDate        2022-02-15 00:00:00.000  2022-01-31 00:00:00.000  ...
# dividendYield                             2.17                     2.73  ...
# epsChange                                    0                        0  ...
# epsChangePercentTTM                     6.9466                  72.7096  ...
# epsChangeYear                          12.6406                        0  ...
# epsTTM                                 5.65832                  15.3438  ...
# grossMarginMRQ                         49.1051                        0  ...
# grossMarginTTM                         49.2737                        0  ...
# high52                                  165.35                   172.96  ...
# interestCoverage                       53.8333                        0  ...
# low52                                   121.54                   128.19  ...
# ltDebtToEquity                         50.0291                  102.338  ...
# marketCap                               384729                   433272  ...
# marketCapFloat                         2394.45                  2939.32  ...
# netProfitMarginMRQ                     20.2453                  35.5436  ...
# netProfitMarginTTM                     18.5396                  39.7323  ...
# operatingMarginMRQ                     24.6647                  43.2614  ...
# operatingMarginTTM                     22.3572                  48.9622  ...
# pbRatio                                 8.7914                  1.66468  ...
# pcfRatio                                22.586                  10.1322  ...
# peRatio                                28.3653                  9.55503  ...
# pegRatio                               4.08334                 0.131414  ...
# prRatio                                4.91064                  3.56165  ...
# quickRatio                             0.49628                        0  ...
# returnOnAssets                         12.0276                  1.35611  ...
# returnOnEquity                          31.257                  18.2874  ...
# returnOnInvestment                     16.9761                        0  ...
# revChangeIn                             3.0239                  3.72238  ...
# revChangeTTM                           5.90875                        0  ...
# revChangeYear                                0                        0  ...
# sharesOutstanding                  2.39707e+09              2.95527e+09  ...
# shortIntDayToCover                           0                        0  ...
# shortIntToFloat                              0                        0  ...
# ticker                                      PG                      JPM  ...
# totalDebtToCapital                     44.2642                        0  ...
# totalDebtToEquity                      79.9072                  186.633  ...
# vol10DayAvg                        1.10989e+07              2.30243e+07  ...
# vol1DayAvg                         1.10869e+07              2.30161e+07  ...
# vol3MonthAvg                       1.71427e+08              2.71830e+08  ...
# Annual_Return_Percent                 0.231206                 0.126816  ...
#
#                                            480          481  \
# beta                                   1.77229      1.07594
# bookValuePerShare                      2.18207      10.5029
# currentRatio                            1.4948       1.9958
# divGrowthRate3Year                           0            0
# dividendAmount                               1            0
# dividendDate           2021-12-07 00:00:00.000
# dividendPayAmount                         0.25            0
# dividendPayDate        2021-12-22 00:00:00.000
# dividendYield                             1.66            0
# epsChange                                    0            0
# epsChangePercentTTM                    508.783            0
# epsChangeYear                          2221.48            0
# epsTTM                                 6.45059      1.87429
# grossMarginMRQ                         42.9783      51.5238
# grossMarginTTM                         40.8545       60.984
# high52                                    64.8        78.14
# interestCoverage                       5.86364      3.85714
# low52                                    42.68       21.655
# ltDebtToEquity                         80.7341       124.33
# marketCap                              8371.75      13576.3
# marketCapFloat                         126.174      479.895
# netProfitMarginMRQ                     5.28261      6.25397
# netProfitMarginTTM                      5.1481      11.9764
# operatingMarginMRQ                     8.41304       10.254
# operatingMarginTTM                     7.05111      16.6022
# pbRatio                                1.73245      1.18318
# pcfRatio                               4.57223       2.1353
# peRatio                                9.32628      14.4855
# pegRatio                              0.018331            0
# prRatio                                0.43889      1.14182
# quickRatio                              0.5702            0
# returnOnAssets                         6.25577      4.20332
# returnOnEquity                         20.1044       8.7197
# returnOnInvestment                     8.28238       4.9167
# revChangeIn                            3.44052      2.87394
# revChangeTTM                           14.5921      11.5489
# revChangeYear                                0            0
# sharesOutstanding                  1.39158e+08  1.69207e+08
# shortIntDayToCover                           0            0
# shortIntToFloat                              0            0
# ticker                                     KSS        DISCA
# totalDebtToCapital                     45.3871      52.4607
# totalDebtToEquity                      83.1069      127.336
# vol10DayAvg                        1.09655e+07  1.03212e+07
# vol1DayAvg                         1.09479e+07    1.032e+07
# vol3MonthAvg                       1.14945e+08  1.67231e+08
# Annual_Return_Percent                 0.316699    -0.338128
#
#                                            482                      483  \
# beta                                   1.67598                  1.45894
# bookValuePerShare                      8.48708                  1.77128
# currentRatio                           1.66172                  2.13042
# divGrowthRate3Year                           0                        0
# dividendAmount                               1                        0
# dividendDate           2021-12-30 00:00:00.000
# dividendPayAmount                         0.25                     0.35
# dividendPayDate        2022-01-31 00:00:00.000  2021-03-10 00:00:00.000
# dividendYield                             4.87                        0
# epsChange                                    0                        0
# epsChangePercentTTM                          0                  210.633
# epsChangeYear                                0                  11608.2
# epsTTM                                       0                  2.89229
# grossMarginMRQ                         32.8644                  18.4032
# grossMarginTTM                         34.2853                  19.2477
# high52                                   26.96                    42.39
# interestCoverage                          3.92                  11.8513
# low52                                    17.59                   27.165
# ltDebtToEquity                         77.3333                  53.6492
# marketCap                              3663.07                  5688.99
# marketCapFloat                         176.918                  161.449
# netProfitMarginMRQ                           0                  6.46184
# netProfitMarginTTM                           0                  3.73906
# operatingMarginMRQ                           0                  6.34795
# operatingMarginTTM                           0                  4.56336
# pbRatio                                0.73732                  0.99339
# pcfRatio                                     0                  5.26745
# peRatio                                      0                  12.1046
# pegRatio                                     0                 0.057468
# prRatio                                0.52047                  0.36311
# quickRatio                             1.41569                  1.20729
# returnOnAssets                               0                  4.78661
# returnOnEquity                               0                  8.50426
# returnOnInvestment                           0                  5.84269
# revChangeIn                            1.08077                  2.35816
# revChangeTTM                           0.22786                  23.7074
# revChangeYear                                0                        0
# sharesOutstanding                  1.59394e+08              1.62496e+08
# shortIntDayToCover                           0                        0
# shortIntToFloat                              0                        0
# ticker                                     XRX                      HFC
# totalDebtToCapital                     47.6383                   32.678
# totalDebtToEquity                      91.3118                  53.6492
# vol10DayAvg                        3.49216e+06              2.11166e+06
# vol1DayAvg                         3.49216e+06              2.11166e+06
# vol3MonthAvg                       5.81309e+07              3.68759e+07
# Annual_Return_Percent               -0.0329877                 0.177202
#
#                                            484                      485  \
# beta                                    1.8857                  0.76689
# bookValuePerShare                            0                        0
# currentRatio                           1.51649                  1.98647
# divGrowthRate3Year                           0                        0
# dividendAmount                               0                     1.08
# dividendDate                                    2021-12-03 00:00:00.000
# dividendPayAmount                         0.13                     0.27
# dividendPayDate        2019-12-04 00:00:00.000  2022-01-03 00:00:00.000
# dividendYield                                0                     4.81
# epsChange                                    0                        0
# epsChangePercentTTM                    102.949                        0
# epsChangeYear                          37.4314                  28.2008
# epsTTM                                 0.38869                        0
# grossMarginMRQ                         13.6381                        0
# grossMarginTTM                         12.8517                        0
# high52                                  11.665                  26.5132
# interestCoverage                       1.06127                        0
# low52                                     5.55                   17.195
# ltDebtToEquity                         57.9023                  12780.2
# marketCap                              2916.03                  3946.39
# marketCapFloat                         446.439                  174.016
# netProfitMarginMRQ                           0                        0
# netProfitMarginTTM                     2.48727                        0
# operatingMarginMRQ                      1.2663                        0
# operatingMarginTTM                     1.15334                        0
# pbRatio                                0.83366                  253.977
# pcfRatio                               4.79611                        0
# peRatio                                16.6457                        0
# pegRatio                              0.161688                        0
# prRatio                                0.35106                        0
# quickRatio                             1.20968                        0
# returnOnAssets                         1.41678                        0
# returnOnEquity                         4.57183                        0
# returnOnInvestment                     2.69226                        0
# revChangeIn                                  0                        0
# revChangeTTM                                 0                        0
# revChangeYear                                0                        0
# sharesOutstanding                    4.507e+08              1.75629e+08
# shortIntDayToCover                           0                        0
# shortIntToFloat                              0                        0
# ticker                                     FTI                      HRB
# totalDebtToCapital                     39.6039                  99.2236
# totalDebtToEquity                      65.9918                  12780.2
# vol10DayAvg                        1.12672e+07              2.30594e+06
# vol1DayAvg                         1.12671e+07              2.30537e+06
# vol3MonthAvg                       1.36248e+08              3.99083e+07
# Annual_Return_Percent                -0.409132                 0.278157
#
#                                486          487                      488  \
# beta                       1.26181      1.26181                  1.31229
# bookValuePerShare                0            0                        0
# currentRatio               2.30923      2.30923                  1.33619
# divGrowthRate3Year               0            0                        0
# dividendAmount                   0            0                      0.2
# dividendDate                                     2021-09-14 00:00:00.000
# dividendPayAmount                0            0                      0.1
# dividendPayDate                                  2021-10-13 00:00:00.000
# dividendYield                    0            0                     0.92
# epsChange                        0            0                        0
# epsChangePercentTTM        155.155      155.155                  148.353
# epsChangeYear              181.168      181.168                  472.963
# epsTTM                     0.91196      0.91196                  0.82873
# grossMarginMRQ             50.9924      50.9924                  50.2798
# grossMarginTTM             50.0031      50.0031                  49.5946
# high52                       27.28       22.995                    26.21
# interestCoverage           20.4427      20.4427                        0
# low52                        17.29        14.77                     18.3
# ltDebtToEquity             33.5181      33.5181                   23.922
# marketCap                  7890.62      7890.62                  12896.5
# marketCapFloat             386.992      386.992                  511.522
# netProfitMarginMRQ         7.39972      7.39972                  10.6715
# netProfitMarginTTM         7.56096      7.56096                  6.25064
# operatingMarginMRQ          11.133       11.133                  13.5092
# operatingMarginTTM         8.20444      8.20444                  7.34887
# pbRatio                    4.39558      4.39558                  1.57079
# pcfRatio                   13.8699      13.8699                  9.99725
# peRatio                    20.0228      20.0228                   26.257
# pegRatio                   0.12905      0.12905                  0.17699
# prRatio                    1.41968      1.41968                  1.32366
# quickRatio                 1.69076      1.69076                  1.24205
# returnOnAssets              8.6774       8.6774                  3.95224
# returnOnEquity             24.4117      24.4117                  6.20859
# returnOnInvestment         12.2111      12.2111                  5.28302
# revChangeIn                14.3539      14.3539                  0.40128
# revChangeTTM               23.1798      23.1798                  10.9049
# revChangeYear                    0            0                        0
# sharesOutstanding      1.88646e+08  2.53019e+08               1.9963e+08
# shortIntDayToCover               0            0                        0
# shortIntToFloat                  0            0                        0
# ticker                         UAA           UA                      NWS
# totalDebtToCapital         25.1038      25.1038                  19.8388
# totalDebtToEquity          33.5181      33.5181                  27.5761
# vol10DayAvg            7.19467e+06  3.53168e+06                   523696
# vol1DayAvg             7.19074e+06  7.19074e+06              2.83972e+06
# vol3MonthAvg           1.32481e+08  1.32481e+08               6.9509e+07
# Annual_Return_Percent    0.0252667    0.0263678                 0.151323
#
#                                            489
# beta                                   2.48883
# bookValuePerShare                      28.4375
# currentRatio                           0.67068
# divGrowthRate3Year                           0
# dividendAmount                               0
# dividendDate
# dividendPayAmount                        0.125
# dividendPayDate        2020-03-27 00:00:00.000
# dividendYield                                0
# epsChange                                    0
# epsChangePercentTTM                    84.3866
# epsChangeYear                          24.9976
# epsTTM                                       0
# grossMarginMRQ                          63.199
# grossMarginTTM                          61.183
# high52                                   11.12
# interestCoverage                        0.5903
# low52                                     6.22
# ltDebtToEquity                         175.856
# marketCap                              6654.21
# marketCapFloat                         337.858
# netProfitMarginMRQ                     16.6873
# netProfitMarginTTM                     0.78934
# operatingMarginMRQ                     1.25392
# operatingMarginTTM                     0.70938
# pbRatio                                2.04792
# pcfRatio                               16.1903
# peRatio                                      0
# pegRatio                                     0
# prRatio                                1.36427
# quickRatio                              0.4556
# returnOnAssets                           0.242
# returnOnEquity                               0
# returnOnInvestment                     0.31458
# revChangeIn                            29.1133
# revChangeTTM                           10.0842
# revChangeYear                                0
# sharesOutstanding                  8.18476e+08
# shortIntDayToCover                           0
# shortIntToFloat                              0
# ticker                                    COTY
# totalDebtToCapital                     63.4427
# totalDebtToEquity                       188.75
# vol10DayAvg                        9.86118e+06
# vol1DayAvg                         9.86076e+06
# vol3MonthAvg                       1.76455e+08
# Annual_Return_Percent                 0.204444
#
# [47 rows x 490 columns]

# %% [markdown]
# Think back to other accounting and finance courses, and assess whether you think the operating metrics of these companies seem to portray a healthy company, or not, and if they seem overvalued based on PE or PS measures.  Remember, there really is no right or wrong answer here.

# %% [markdown]
# ## Get Annual Return Data
# The below cell pulls the annual return data from TD Ameritrade, cleans it up into a useable format and spits it out in a nice table format using the Pandas package.

# %%
annual_returns_df=get_annual_returns(tickers,key)
annual_returns_df
# Out:
# error with ALXN
# error with KSU
# error with MXIM
# error with VAR
# error with TIF
# error with ETFC
# error with CTL
# error with CXO
# error with MYL
# error with COG
# error with LB
# error with FLIR
# error with NBL
#     ticker  Annual_Return_Percent
# 0     AAPL               0.242468
# 1     MSFT               0.290169
# 2     AMZN              -0.110594
# 3       FB               0.138528
# 4    GOOGL               0.439143
# ..     ...                    ...
# 487    HRB               0.278157
# 488    UAA               0.025267
# 489     UA               0.026368
# 490    NWS               0.151323
# 491   COTY               0.204444
#
# [492 rows x 2 columns]

# %% [markdown]
# ## Fundamental Data Frame Info
# The next few code blocks give us information on how our data is structered, the columns it contains, the data types of the columns (string, integer, float, etc.), summary statistics, null values, etc.

# %%
for col in fundamental_data.columns:
    try:
        fundamental_data[col]=fundamental_data[col].astype('float')
    except:
        pass

#Data columns
fundamental_data.columns
# Out:
# Index(['beta', 'bookValuePerShare', 'currentRatio', 'divGrowthRate3Year',
#        'dividendAmount', 'dividendDate', 'dividendPayAmount',
#        'dividendPayDate', 'dividendYield', 'epsChange', 'epsChangePercentTTM',
#        'epsChangeYear', 'epsTTM', 'grossMarginMRQ', 'grossMarginTTM', 'high52',
#        'interestCoverage', 'low52', 'ltDebtToEquity', 'marketCap',
#        'marketCapFloat', 'netProfitMarginMRQ', 'netProfitMarginTTM',
#        'operatingMarginMRQ', 'operatingMarginTTM', 'pbRatio', 'pcfRatio',
#        'peRatio', 'pegRatio', 'prRatio', 'quickRatio', 'returnOnAssets',
#        'returnOnEquity', 'returnOnInvestment', 'revChangeIn', 'revChangeTTM',
#        'revChangeYear', 'sharesOutstanding', 'shortIntDayToCover',
#        'shortIntToFloat', 'ticker', 'totalDebtToCapital', 'totalDebtToEquity',
#        'vol10DayAvg', 'vol1DayAvg', 'vol3MonthAvg', 'Annual_Return_Percent'],
#       dtype='object')

# %%
#General data statistics
fundamental_data.describe()
# Out:
#              beta  bookValuePerShare  currentRatio  divGrowthRate3Year  \
# count  490.000000         490.000000    490.000000               490.0
# mean     1.049562           9.013958      1.365174                 0.0
# std      0.467636          11.813854      1.290471                 0.0
# min      0.000000           0.000000      0.000000                 0.0
# 25%      0.765840           0.000000      0.677662                 0.0
# 50%      1.055755           6.069205      1.191565                 0.0
# 75%      1.311472          12.548785      1.768882                 0.0
# max      4.153940         102.553600     11.992690                 0.0
#
#        dividendAmount  dividendPayAmount  dividendYield  epsChange  \
# count      490.000000         490.000000     490.000000      490.0
# mean         1.915676           0.547104       1.696796        0.0
# std          2.079957           1.099831       1.433470        0.0
# min          0.000000           0.000000       0.000000        0.0
# 25%          0.410000           0.170000       0.520000        0.0
# 50%          1.480000           0.390000       1.515000        0.0
# 75%          2.720000           0.698750       2.620000        0.0
# max         19.520000          22.000000       8.250000        0.0
#
#        epsChangePercentTTM  epsChangeYear  ...  revChangeYear  \
# count           490.000000     490.000000  ...          490.0
# mean            133.068425     156.162227  ...            0.0
# std             426.037107     773.147225  ...            0.0
# min               0.000000       0.000000  ...            0.0
# 25%               6.602780       0.000000  ...            0.0
# 50%              40.219360      24.368940  ...            0.0
# 75%             105.523550      84.493378  ...            0.0
# max            5959.020000   11608.230000  ...            0.0
#
#        sharesOutstanding  shortIntDayToCover  shortIntToFloat  \
# count       4.900000e+02               490.0            490.0
# mean        6.149221e+08                 0.0              0.0
# std         1.152534e+09                 0.0              0.0
# min         3.482747e+06                 0.0              0.0
# 25%         1.528712e+08                 0.0              0.0
# 50%         3.018693e+08                 0.0              0.0
# 75%         6.083795e+08                 0.0              0.0
# max         1.631944e+10                 0.0              0.0
#
#        totalDebtToCapital  totalDebtToEquity   vol10DayAvg    vol1DayAvg  \
# count          490.000000         490.000000  4.900000e+02  4.900000e+02
# mean            46.242702         167.436423  5.951197e+06  5.973625e+06
# std             44.590275         651.253516  1.207872e+07  1.205726e+07
# min              0.000000           0.000000  0.000000e+00  2.835000e+04
# 25%             26.457283          31.660387  1.294578e+06  1.335935e+06
# 50%             41.095915          66.210555  2.457987e+06  2.502560e+06
# 75%             59.188538         130.888650  5.450546e+06  5.511912e+06
# max            538.147200       12780.220000  1.340429e+08  1.339024e+08
#
#        vol3MonthAvg  Annual_Return_Percent
# count  4.900000e+02             490.000000
# mean   9.928146e+07               0.189817
# std    2.024890e+08               0.262833
# min    4.604300e+05              -0.409132
# 25%    2.175464e+07               0.026814
# 50%    4.123446e+07               0.167825
# 75%    9.283022e+07               0.322700
# max    2.316439e+09               1.997093
#
# [8 rows x 44 columns]

# %%
# Data Frame information (null, data type etc)
fundamental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   beta                   490 non-null    float64
#  1   bookValuePerShare      490 non-null    float64
#  2   currentRatio           490 non-null    float64
#  3   divGrowthRate3Year     490 non-null    float64
#  4   dividendAmount         490 non-null    float64
#  5   dividendDate           490 non-null    object
#  6   dividendPayAmount      490 non-null    float64
#  7   dividendPayDate        490 non-null    object
#  8   dividendYield          490 non-null    float64
#  9   epsChange              490 non-null    float64
#  10  epsChangePercentTTM    490 non-null    float64
#  11  epsChangeYear          490 non-null    float64
#  12  epsTTM                 490 non-null    float64
#  13  grossMarginMRQ         490 non-null    float64
#  14  grossMarginTTM         490 non-null    float64
#  15  high52                 490 non-null    float64
#  16  interestCoverage       490 non-null    float64
#  17  low52                  490 non-null    float64
#  18  ltDebtToEquity         490 non-null    float64
#  19  marketCap              490 non-null    float64
#  20  marketCapFloat         490 non-null    float64
#  21  netProfitMarginMRQ     490 non-null    float64
#  22  netProfitMarginTTM     490 non-null    float64
#  23  operatingMarginMRQ     490 non-null    float64
#  24  operatingMarginTTM     490 non-null    float64
#  25  pbRatio                490 non-null    float64
#  26  pcfRatio               490 non-null    float64
#  27  peRatio                490 non-null    float64
#  28  pegRatio               490 non-null    float64
#  29  prRatio                490 non-null    float64
#  30  quickRatio             490 non-null    float64
#  31  returnOnAssets         490 non-null    float64
#  32  returnOnEquity         490 non-null    float64
#  33  returnOnInvestment     490 non-null    float64
#  34  revChangeIn            490 non-null    float64
#  35  revChangeTTM           490 non-null    float64
#  36  revChangeYear          490 non-null    float64
#  37  sharesOutstanding      490 non-null    float64
#  38  shortIntDayToCover     490 non-null    float64
#  39  shortIntToFloat        490 non-null    float64
#  40  ticker                 490 non-null    object
#  41  totalDebtToCapital     490 non-null    float64
#  42  totalDebtToEquity      490 non-null    float64
#  43  vol10DayAvg            490 non-null    float64
#  44  vol1DayAvg             490 non-null    float64
#  45  vol3MonthAvg           490 non-null    float64
#  46  Annual_Return_Percent  490 non-null    float64
# dtypes: float64(44), object(3)
# memory usage: 180.0+ KB

# %%
# Uncorrelated features are generally more powerful predictors
colormap = plt.cm.viridis
plt.figure(figsize=(40, 40))
plt.title('Pearson Correlation of Features', y=1.05, size=14)
sns.set(font_scale=1.4)
sns.heatmap(fundamental_data.corr().round(2)\
            ,linewidths=0.1,vmax=1.0, square=True, cmap=colormap, \
            linecolor='white', annot=True);

# %% [markdown]
# ## -------------PRACTICE-------------

# %% [markdown]
# 1. Pick a stock we haven't looked at and grab its fundamental data.

# %% [markdown]
# 2. Calculate the annual volatility of TQQQ.

# %% [markdown]
# 3. Find the beta too SPY of AMD as well as its volatility and make a conclusion about its risk profile.

# %% [markdown]
# 4. Get the fundamental data of AMC.

# %% [markdown]
# ## Linear Regression
# Linear regression models are a great way to test if ratios are even worth looking at.  Lets check based on the stocks we picked above

# %%
x = fundamental_data[['epsTTM', 'grossMarginMRQ', 'grossMarginTTM','interestCoverage',
                      'netProfitMarginMRQ', 'netProfitMarginTTM','operatingMarginMRQ', 'operatingMarginTTM','peRatio', 'pegRatio', 'prRatio', 'quickRatio', 'returnOnAssets',
                      'returnOnEquity', 'returnOnInvestment']] # Independent variable
y = fundamental_data["Annual_Return_Percent"] # Response / Target Variable

print(x.shape, y.shape)
x=sm.add_constant(x)
result=sm.OLS(y,x).fit()
print(result.summary())
# Out:
# (490, 15) (490,)
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Annual_Return_Percent   R-squared:                       0.067
# Model:                               OLS   Adj. R-squared:                  0.038
# Method:                    Least Squares   F-statistic:                     2.275
# Date:                   Sun, 30 Jan 2022   Prob (F-statistic):            0.00413
# Time:                           16:35:12   Log-Likelihood:                -22.993
# No. Observations:                    490   AIC:                             77.99
# Df Residuals:                        474   BIC:                             145.1
# Df Model:                             15
# Covariance Type:               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.1713      0.026      6.590      0.000       0.120       0.222
# epsTTM                 0.0004      0.001      0.567      0.571      -0.001       0.002
# grossMarginMRQ         0.0043      0.002      1.775      0.076      -0.000       0.009
# grossMarginTTM        -0.0050      0.002     -2.052      0.041      -0.010      -0.000
# interestCoverage   -9.076e-07   3.02e-05     -0.030      0.976   -6.03e-05    5.85e-05
# netProfitMarginMRQ     0.0002      0.001      0.151      0.880      -0.002       0.002
# netProfitMarginTTM    -0.0003      0.002     -0.116      0.907      -0.005       0.004
# operatingMarginMRQ     0.0045      0.002      2.321      0.021       0.001       0.008
# operatingMarginTTM  2.475e-05      0.003      0.010      0.992      -0.005       0.005
# peRatio             6.738e-05      0.000      0.449      0.654      -0.000       0.000
# pegRatio              -0.0004      0.002     -0.202      0.840      -0.004       0.004
# prRatio               -0.0021      0.003     -0.710      0.478      -0.008       0.004
# quickRatio            -0.0239      0.013     -1.862      0.063      -0.049       0.001
# returnOnAssets        -0.0041      0.005     -0.788      0.431      -0.014       0.006
# returnOnEquity      6.961e-06   4.01e-05      0.174      0.862   -7.18e-05    8.57e-05
# returnOnInvestment     0.0015      0.003      0.472      0.637      -0.005       0.008
# ==============================================================================
# Omnibus:                      193.401   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1178.354
# Skew:                           1.599   Prob(JB):                    1.33e-256
# Kurtosis:                       9.891   Cond. No.                         883.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Regression Results
# The above regression results show us that by looking at a handful of fundamental metrics, we are able to explain only 7% of the movement in the stocks analyzed (per R-squared).  Additionally, it is usefuly to look at the Prob (F-statistic) and Prob(Jarque-Bera) as these two statistical tests are crucial gauges of model efficacy.  Specifically, if both values are under .05, we can reasonable assume the variables used in the model are meaningful indicators.
#
# While these results suggest maybe fundamental analysis isn't the best predictor, it may also be a signal that something unrelated to the companies themselves is driving performance.

# %% [markdown]
# ## Remark: Volatility doesn't live in a vacuum
# In our previous exploration of volatility, we only examined the volatility of individual assets.  While this is certainly useful information, understanding how assets behave together can be even more insightful.  After all, who only invests in a single asset?
#
# Unlike using a weighted average to quickly find a portfolios return, we have to use the square root of the following formula to gauge a portfolio's volatility.  This is incredibly important, as often times, a portfolio can be made up of extremely volatile assets, but, because of their relationships, the net volatility is relatively low.
#
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/c91273fd3499f6172ed9baf853d3d3ae8d02c62d">

# %%
#Let's use the formula above to find the volatility find the volatility of a portfolio of half AMD and half AMC

amd_weight = .5
amc_weight = .5
tickers = ['AMD','AMC']

###Grab Price History
price_hist = scrub_price_hist(tickers,key)
price_hist = price_hist[['close','ticker','datetime']]


###Calculate Portfolio Volatility
count = 0
for ticker in tickers:
    if count == 0:
        temp = price_hist[price_hist['ticker'] == ticker]
        temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1
        temp = temp.dropna()
        temp = temp.drop(['close','ticker'], axis = 1)
        master = temp
        count = 1
    else:
        temp = price_hist[price_hist['ticker'] == ticker]
        temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1
        temp = temp.dropna()
        temp = temp.drop(['close','ticker'], axis = 1)
        master = pd.merge(master,temp,how = 'left',on = ['datetime'])


consol_returns = pd.DataFrame([master[tickers[0] + '_Return_%']*amd_weight,master[tickers[1] + '_Return_%']*amc_weight]).T
port_volatility = math.sqrt(consol_returns.cov().to_numpy().sum())*math.sqrt(252)

###Calculate Individual Security Volatilities
sec_vols = []        
for ticker in tickers:
    temp = [ticker,(math.sqrt(252)*math.sqrt(statistics.variance(master[ticker + '_Return_%'])))]
    sec_vols.append(temp)
    
    
for i in range (0,len(tickers)):
    print(tickers[i] + ' Volatility: ',round(sec_vols[i][1]*100,2),'%')
print('Portfolio Volatility: ',round(port_volatility*100,2),'%')
# Out:
# AMD Volatility:  44.96 %
# AMC Volatility:  158.28 %
# Portfolio Volatility:  85.6 %
# <ipython-input-12-b19ea9393863>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1
# <ipython-input-12-b19ea9393863>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1

# %% [markdown]
# Notice how the volatility of the portfolio is significantly less than had you only held AMC.  Conversely,  consider the implications of the volatility of these holdings.

# %% [markdown]
# ## -------------PRACTICE-------------

# %% [markdown]
# 1. Find the annualized volatility of an equally weighted portfolio of AMGN and PG.  Assume 252 trading days in a year and use one year of historicals.

# %% [markdown]
# 2. Find the annualized volatility of AMGN and PG respecively with the same assumptions as question 1.

# %% [markdown]
# 3. Find the volatility of XRX using data from June of 2021 only.  Compare it to its volatility in September of 2021.

# %% [markdown]
# ## TD API: A Risk Management Study
# Understanding the risk of a portfolio of stocks is often times just as crucial, if not more so, than understanding its growth opportunities.  In this exercise we will examine a portfolio that has equal weights in APPL and TSLA, and attempt to gauge how much capital we are putting at risk by holding this portfolio.  To keep math simple, we will assume that the portfolio is valued at $50,000.
#
# ## Value at Risk
# Value at Risk, or simply VaR, has been around for decades, and is considered a gold standard for the benchmark of porfolio risk.  Barring any significant shifts in company health or direction, VaR can be thought of as largest paper loss an investor will see over a predefined time horizon by holding a security(s).  We will look at one month VaR, and choose a confidence level of 95% in order to have a high degree of confidence that we are in fact looking at a reasonable worst case.  While it can be beneficial to look at the 99% case, 95% will be a good start.  With our parameters defined, VaR can be calculated as follows:
#
# VaR = Portfolio Volatility * Portfolio Value * 1.65
#
# note that the 1.65 translates to a 95% confidence intervals z-score

# %%
###Define Portfolio Inputs
aapl_weight = .5
tsla_weight = .5
portfolio_value = 50000
days_into_future = 22  ##remember, there are only 252 trading days in a year!
tickers = ['TSLA','AAPL']

# %%
###Grab Price History
price_hist = scrub_price_hist(tickers,key)
price_hist = price_hist[['close','ticker','datetime']]


###Calculate Portfolio Volatility
count = 0
for ticker in tickers:
    if count == 0:
        temp = price_hist[price_hist['ticker'] == ticker]
        temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1
        temp = temp.dropna()
        temp = temp.drop(['close','ticker'], axis = 1)
        master = temp
        count = 1
    else:
        temp = price_hist[price_hist['ticker'] == ticker]
        temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1
        temp = temp.dropna()
        temp = temp.drop(['close','ticker'], axis = 1)
        master = pd.merge(master,temp,how = 'left',on = ['datetime'])


consol_returns = pd.DataFrame([master[tickers[0] + '_Return_%']*tsla_weight,master[tickers[1] + '_Return_%']*aapl_weight]).T
port_volatility = math.sqrt(consol_returns.cov().to_numpy().sum())*math.sqrt(days_into_future)

###Calculate Individual Security Volatilities
sec_vols = []        
for ticker in tickers:
    temp = [ticker,(math.sqrt(days_into_future)*math.sqrt(statistics.variance(master[ticker + '_Return_%'])))]
    sec_vols.append(temp)



###Compare individual security volatility to Portfolio Volatility
for i in range (0,len(tickers)):
    print(tickers[i] + ' Volatility: ',round(sec_vols[i][1]*100,2),'%')
print('Portfolio Volatility: ',round(port_volatility*100,2),'%')
# Out:
# TSLA Volatility:  16.92 %
# AAPL Volatility:  7.31 %
# Portfolio Volatility:  10.66 %
# <ipython-input-8-ed845843d488>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1
# <ipython-input-8-ed845843d488>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[ticker +'_Return_%'] = temp['close'] / temp['close'].shift(1) - 1

# %%
###Calculate VaR
VaR = portfolio_value * 1.65 * port_volatility
print('$',round(VaR,2))
# Out:
# $ 8795.9

# %% [markdown]
# ## Conclusions
#
# By holding a \\$50,000 portfolio that is equally weighted in AAPL and TSLA stock, an investor should be comfortable with a significant likelihood of losing \\$8,700+ over the course of one month.
